# %%
import dgl
from dgl.data.utils import load_graphs

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

from model.model import HTGNN, LinkPredictor
from utils.pytorchtools import EarlyStopping
from utils.utils import compute_metric, compute_loss
from utils.data import load_MAG_data

dgl.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.cuda.manual_seed_all(0)
# Out:
# Using backend: pytorch

# %%
def evaluate(model, val_feats, val_labels):
    val_mae_list, val_rmse_list = [], []
    model.eval()
    with torch.no_grad():
        for (G_feat, (pos_label, neg_label)) in zip(val_feats, val_labels):

            G_feat = G_feat.to(device)
            pos_label = pos_label.to(device)
            neg_label = neg_label.to(device)

            h = model[0](G_feat, 'author')
            pos_score = model[1](pos_label, h)
            neg_score = model[1](neg_label, h)

            loss = compute_loss(pos_score, neg_score, device)
            auc, ap = compute_metric(pos_score, neg_score)
    
    return auc, ap

# %%
glist, label_dict = load_graphs('data/ogbn_graphs.bin')
device = torch.device('cuda:0')
time_window = 3

train_feats, train_labels, val_feats, val_labels, test_feats, test_labels = load_MAG_data(glist, time_window, device)

graph_atom = test_feats[0]
model_out_path = 'output/OGBN-MAG'
auc_list, ap_list = [], []

for k in range(5):
    htgnn = HTGNN(graph=graph_atom, n_inp=128, n_hid=32, n_layers=2, n_heads=1, time_window=time_window, norm=True, device=device)
    predictor = LinkPredictor(n_inp=32, n_classes=1)
    model = nn.Sequential(htgnn, predictor).to(device)

    print(f'---------------Repeat time: {k+1}---------------------')
    print(f'# params: {sum(p.numel() for p in model.parameters() if p.requires_grad)}')
    optim = torch.optim.Adam(model.parameters(), lr=5e-3, weight_decay=5e-4)

    early_stopping = EarlyStopping(patience=50, verbose=True, path=f'{model_out_path}/checkpoint_HTGNN_{k}.pt')
    for epoch in range(500):
        model.train()
        for (G_feat, (pos_label, neg_label)) in zip(train_feats, train_labels):

            G_feat = G_feat.to(device)

            pos_label = pos_label.to(device)
            neg_label = neg_label.to(device)

            h = model[0](G_feat, 'author')

            pos_score = model[1](pos_label, h)
            neg_score = model[1](neg_label, h)
            
            loss = compute_loss(pos_score, neg_score, device)
            auc, ap = compute_metric(pos_score, neg_score)

            optim.zero_grad()
            loss.backward()
            optim.step()
        
        auc, ap = evaluate(model, val_feats, val_labels)
        early_stopping(loss, model)

        if early_stopping.early_stop:
            print("Early stopping")
            break

    model.load_state_dict(torch.load(f'{model_out_path}/checkpoint_HTGNN_{k}.pt'))
    auc, ap = evaluate(model, test_feats, test_labels)

    print(f'auc: {auc}, ap: {ap}')
    auc_list.append(auc)
    ap_list.append(ap)
# Out:
# loading mp2vec
# generating train, val, test sets
# ---------------Repeat time: 1---------------------
# # params: 127817
# Validation loss decreased (inf --> 0.668988).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.668988 --> 0.657884).  Saving model ...
# Validation loss decreased (0.657884 --> 0.575683).  Saving model ...
# Validation loss decreased (0.575683 --> 0.522445).  Saving model ...
# Validation loss decreased (0.522445 --> 0.497960).  Saving model ...
# Validation loss decreased (0.497960 --> 0.486032).  Saving model ...
# Validation loss decreased (0.486032 --> 0.467850).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.467850 --> 0.430238).  Saving model ...
# Validation loss decreased (0.430238 --> 0.420633).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.420633 --> 0.413914).  Saving model ...
# Validation loss decreased (0.413914 --> 0.412252).  Saving model ...
# Validation loss decreased (0.412252 --> 0.384341).  Saving model ...
# Validation loss decreased (0.384341 --> 0.380375).  Saving model ...
# Validation loss decreased (0.380375 --> 0.370178).  Saving model ...
# Validation loss decreased (0.370178 --> 0.361727).  Saving model ...
# Validation loss decreased (0.361727 --> 0.359831).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# Validation loss decreased (0.359831 --> 0.344902).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.344902 --> 0.334797).  Saving model ...
# Validation loss decreased (0.334797 --> 0.334664).  Saving model ...
# Validation loss decreased (0.334664 --> 0.326082).  Saving model ...
# Validation loss decreased (0.326082 --> 0.325820).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# Validation loss decreased (0.325820 --> 0.318664).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# Validation loss decreased (0.318664 --> 0.317532).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# Validation loss decreased (0.317532 --> 0.311014).  Saving model ...
# Validation loss decreased (0.311014 --> 0.300695).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.300695 --> 0.299522).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.299522 --> 0.294325).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# Validation loss decreased (0.294325 --> 0.291102).  Saving model ...
# Validation loss decreased (0.291102 --> 0.282141).  Saving model ...
# Validation loss decreased (0.282141 --> 0.278646).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# Validation loss decreased (0.278646 --> 0.277547).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.277547 --> 0.273158).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# Validation loss decreased (0.273158 --> 0.272822).  Saving model ...
# Validation loss decreased (0.272822 --> 0.267608).  Saving model ...
# Validation loss decreased (0.267608 --> 0.266371).  Saving model ...
# Validation loss decreased (0.266371 --> 0.264666).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.264666 --> 0.259774).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# Validation loss decreased (0.259774 --> 0.256837).  Saving model ...
# Validation loss decreased (0.256837 --> 0.254902).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# Validation loss decreased (0.254902 --> 0.251458).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# Validation loss decreased (0.251458 --> 0.249874).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.249874 --> 0.247231).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# Validation loss decreased (0.247231 --> 0.246908).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# Validation loss decreased (0.246908 --> 0.242938).  Saving model ...
# Validation loss decreased (0.242938 --> 0.241335).  Saving model ...
# Validation loss decreased (0.241335 --> 0.241240).  Saving model ...
# Validation loss decreased (0.241240 --> 0.239025).  Saving model ...
# Validation loss decreased (0.239025 --> 0.236733).  Saving model ...
# Validation loss decreased (0.236733 --> 0.233639).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# EarlyStopping counter: 33 out of 50
# EarlyStopping counter: 34 out of 50
# EarlyStopping counter: 35 out of 50
# EarlyStopping counter: 36 out of 50
# EarlyStopping counter: 37 out of 50
# EarlyStopping counter: 38 out of 50
# EarlyStopping counter: 39 out of 50
# EarlyStopping counter: 40 out of 50
# EarlyStopping counter: 41 out of 50
# EarlyStopping counter: 42 out of 50
# EarlyStopping counter: 43 out of 50
# EarlyStopping counter: 44 out of 50
# EarlyStopping counter: 45 out of 50
# EarlyStopping counter: 46 out of 50
# EarlyStopping counter: 47 out of 50
# Validation loss decreased (0.233639 --> 0.232791).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# Validation loss decreased (0.232791 --> 0.229766).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# EarlyStopping counter: 33 out of 50
# Validation loss decreased (0.229766 --> 0.227185).  Saving model ...
# Validation loss decreased (0.227185 --> 0.227080).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# Validation loss decreased (0.227080 --> 0.225533).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.225533 --> 0.222861).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# Validation loss decreased (0.222861 --> 0.220775).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# Validation loss decreased (0.220775 --> 0.219553).  Saving model ...
# Validation loss decreased (0.219553 --> 0.215871).  Saving model ...
# Validation loss decreased (0.215871 --> 0.215251).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# EarlyStopping counter: 33 out of 50
# EarlyStopping counter: 34 out of 50
# EarlyStopping counter: 35 out of 50
# EarlyStopping counter: 36 out of 50
# EarlyStopping counter: 37 out of 50
# EarlyStopping counter: 38 out of 50
# EarlyStopping counter: 39 out of 50
# EarlyStopping counter: 40 out of 50
# EarlyStopping counter: 41 out of 50
# EarlyStopping counter: 42 out of 50
# EarlyStopping counter: 43 out of 50
# EarlyStopping counter: 44 out of 50
# EarlyStopping counter: 45 out of 50
# EarlyStopping counter: 46 out of 50
# EarlyStopping counter: 47 out of 50
# Validation loss decreased (0.215251 --> 0.214760).  Saving model ...
# Validation loss decreased (0.214760 --> 0.211758).  Saving model ...
# Validation loss decreased (0.211758 --> 0.208882).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.208882 --> 0.205748).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# EarlyStopping counter: 33 out of 50
# EarlyStopping counter: 34 out of 50
# EarlyStopping counter: 35 out of 50
# EarlyStopping counter: 36 out of 50
# EarlyStopping counter: 37 out of 50
# EarlyStopping counter: 38 out of 50
# EarlyStopping counter: 39 out of 50
# EarlyStopping counter: 40 out of 50
# EarlyStopping counter: 41 out of 50
# Validation loss decreased (0.205748 --> 0.205576).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# Validation loss decreased (0.205576 --> 0.205366).  Saving model ...
# Validation loss decreased (0.205366 --> 0.205359).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# Validation loss decreased (0.205359 --> 0.205153).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# EarlyStopping counter: 33 out of 50
# EarlyStopping counter: 34 out of 50
# EarlyStopping counter: 35 out of 50
# EarlyStopping counter: 36 out of 50
# EarlyStopping counter: 37 out of 50
# EarlyStopping counter: 38 out of 50
# EarlyStopping counter: 39 out of 50
# EarlyStopping counter: 40 out of 50
# EarlyStopping counter: 41 out of 50
# auc: 0.9216650393035468, ap: 0.909220067171066
# ---------------Repeat time: 2---------------------
# # params: 127817
# Validation loss decreased (inf --> 0.685022).  Saving model ...
# Validation loss decreased (0.685022 --> 0.662796).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# Validation loss decreased (0.662796 --> 0.581225).  Saving model ...
# Validation loss decreased (0.581225 --> 0.560309).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.560309 --> 0.522654).  Saving model ...
# Validation loss decreased (0.522654 --> 0.511796).  Saving model ...
# Validation loss decreased (0.511796 --> 0.490881).  Saving model ...
# Validation loss decreased (0.490881 --> 0.469293).  Saving model ...
# Validation loss decreased (0.469293 --> 0.447492).  Saving model ...
# Validation loss decreased (0.447492 --> 0.442246).  Saving model ...
# Validation loss decreased (0.442246 --> 0.422751).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# Validation loss decreased (0.422751 --> 0.415871).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.415871 --> 0.391145).  Saving model ...
# Validation loss decreased (0.391145 --> 0.379743).  Saving model ...
# Validation loss decreased (0.379743 --> 0.374886).  Saving model ...
# Validation loss decreased (0.374886 --> 0.367868).  Saving model ...
# Validation loss decreased (0.367868 --> 0.358346).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# Validation loss decreased (0.358346 --> 0.355018).  Saving model ...
# Validation loss decreased (0.355018 --> 0.345268).  Saving model ...
# Validation loss decreased (0.345268 --> 0.339697).  Saving model ...
# Validation loss decreased (0.339697 --> 0.335236).  Saving model ...
# Validation loss decreased (0.335236 --> 0.333077).  Saving model ...
# Validation loss decreased (0.333077 --> 0.332758).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# Validation loss decreased (0.332758 --> 0.326434).  Saving model ...
# Validation loss decreased (0.326434 --> 0.318469).  Saving model ...
# Validation loss decreased (0.318469 --> 0.318320).  Saving model ...
# Validation loss decreased (0.318320 --> 0.310563).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.310563 --> 0.308831).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# Validation loss decreased (0.308831 --> 0.308499).  Saving model ...
# Validation loss decreased (0.308499 --> 0.301622).  Saving model ...
# Validation loss decreased (0.301622 --> 0.294544).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.294544 --> 0.293003).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# Validation loss decreased (0.293003 --> 0.291584).  Saving model ...
# Validation loss decreased (0.291584 --> 0.288237).  Saving model ...
# Validation loss decreased (0.288237 --> 0.281774).  Saving model ...
# Validation loss decreased (0.281774 --> 0.281452).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.281452 --> 0.275634).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# Validation loss decreased (0.275634 --> 0.274968).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.274968 --> 0.270878).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.270878 --> 0.269305).  Saving model ...
# Validation loss decreased (0.269305 --> 0.266945).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# Validation loss decreased (0.266945 --> 0.266209).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# Validation loss decreased (0.266209 --> 0.265646).  Saving model ...
# Validation loss decreased (0.265646 --> 0.263937).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.263937 --> 0.259814).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# Validation loss decreased (0.259814 --> 0.257348).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.257348 --> 0.254867).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.254867 --> 0.254166).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.254166 --> 0.252725).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# EarlyStopping counter: 33 out of 50
# EarlyStopping counter: 34 out of 50
# EarlyStopping counter: 35 out of 50
# EarlyStopping counter: 36 out of 50
# EarlyStopping counter: 37 out of 50
# Validation loss decreased (0.252725 --> 0.251276).  Saving model ...
# Validation loss decreased (0.251276 --> 0.246422).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# EarlyStopping counter: 33 out of 50
# EarlyStopping counter: 34 out of 50
# EarlyStopping counter: 35 out of 50
# EarlyStopping counter: 36 out of 50
# EarlyStopping counter: 37 out of 50
# EarlyStopping counter: 38 out of 50
# EarlyStopping counter: 39 out of 50
# EarlyStopping counter: 40 out of 50
# EarlyStopping counter: 41 out of 50
# EarlyStopping counter: 42 out of 50
# EarlyStopping counter: 43 out of 50
# EarlyStopping counter: 44 out of 50
# EarlyStopping counter: 45 out of 50
# EarlyStopping counter: 46 out of 50
# EarlyStopping counter: 47 out of 50
# EarlyStopping counter: 48 out of 50
# EarlyStopping counter: 49 out of 50
# EarlyStopping counter: 50 out of 50
# Early stopping
# auc: 0.9041962570510438, ap: 0.8801280863340364
# ---------------Repeat time: 3---------------------
# # params: 127817
# Validation loss decreased (inf --> 0.677459).  Saving model ...
# Validation loss decreased (0.677459 --> 0.621476).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.621476 --> 0.613208).  Saving model ...
# Validation loss decreased (0.613208 --> 0.538955).  Saving model ...
# Validation loss decreased (0.538955 --> 0.537571).  Saving model ...
# Validation loss decreased (0.537571 --> 0.508451).  Saving model ...
# Validation loss decreased (0.508451 --> 0.480525).  Saving model ...
# Validation loss decreased (0.480525 --> 0.453707).  Saving model ...
# Validation loss decreased (0.453707 --> 0.422389).  Saving model ...
# Validation loss decreased (0.422389 --> 0.400693).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.400693 --> 0.393157).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# Validation loss decreased (0.393157 --> 0.376767).  Saving model ...
# Validation loss decreased (0.376767 --> 0.368265).  Saving model ...
# Validation loss decreased (0.368265 --> 0.360161).  Saving model ...
# Validation loss decreased (0.360161 --> 0.352900).  Saving model ...
# Validation loss decreased (0.352900 --> 0.351696).  Saving model ...
# Validation loss decreased (0.351696 --> 0.343774).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.343774 --> 0.343223).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.343223 --> 0.331061).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# Validation loss decreased (0.331061 --> 0.321919).  Saving model ...
# Validation loss decreased (0.321919 --> 0.320500).  Saving model ...
# Validation loss decreased (0.320500 --> 0.315201).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.315201 --> 0.311779).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# Validation loss decreased (0.311779 --> 0.303357).  Saving model ...
# Validation loss decreased (0.303357 --> 0.301536).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.301536 --> 0.301057).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# Validation loss decreased (0.301057 --> 0.298450).  Saving model ...
# Validation loss decreased (0.298450 --> 0.298079).  Saving model ...
# Validation loss decreased (0.298079 --> 0.293856).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# Validation loss decreased (0.293856 --> 0.293095).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# Validation loss decreased (0.293095 --> 0.292099).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.292099 --> 0.288761).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# Validation loss decreased (0.288761 --> 0.288068).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.288068 --> 0.285283).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# Validation loss decreased (0.285283 --> 0.283463).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# Validation loss decreased (0.283463 --> 0.277655).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# Validation loss decreased (0.277655 --> 0.276261).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.276261 --> 0.270077).  Saving model ...
# Validation loss decreased (0.270077 --> 0.269673).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# Validation loss decreased (0.269673 --> 0.260586).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# Validation loss decreased (0.260586 --> 0.260505).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# Validation loss decreased (0.260505 --> 0.259609).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.259609 --> 0.257276).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# Validation loss decreased (0.257276 --> 0.256234).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# Validation loss decreased (0.256234 --> 0.252598).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# Validation loss decreased (0.252598 --> 0.250889).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# Validation loss decreased (0.250889 --> 0.249011).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# Validation loss decreased (0.249011 --> 0.248872).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# Validation loss decreased (0.248872 --> 0.247564).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.247564 --> 0.243735).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# Validation loss decreased (0.243735 --> 0.242766).  Saving model ...
# Validation loss decreased (0.242766 --> 0.241469).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.241469 --> 0.239659).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# Validation loss decreased (0.239659 --> 0.238450).  Saving model ...
# Validation loss decreased (0.238450 --> 0.234122).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# EarlyStopping counter: 33 out of 50
# EarlyStopping counter: 34 out of 50
# EarlyStopping counter: 35 out of 50
# EarlyStopping counter: 36 out of 50
# Validation loss decreased (0.234122 --> 0.233984).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# Validation loss decreased (0.233984 --> 0.233508).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.233508 --> 0.232406).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# Validation loss decreased (0.232406 --> 0.231807).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# Validation loss decreased (0.231807 --> 0.230385).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# EarlyStopping counter: 33 out of 50
# EarlyStopping counter: 34 out of 50
# EarlyStopping counter: 35 out of 50
# ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# Validation loss decreased (0.259777 --> 0.254994).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.254994 --> 0.251778).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# Validation loss decreased (0.251778 --> 0.251320).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# Validation loss decreased (0.251320 --> 0.249125).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# Validation loss decreased (0.249125 --> 0.247576).  Saving model ...
# Validation loss decreased (0.247576 --> 0.244230).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# Validation loss decreased (0.244230 --> 0.242934).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# Validation loss decreased (0.242934 --> 0.240657).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# Validation loss decreased (0.240657 --> 0.236754).  Saving model ...
# Validation loss decreased (0.236754 --> 0.232778).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# Validation loss decreased (0.232778 --> 0.231692).  Saving model ...
# Validation loss decreased (0.231692 --> 0.231589).  Saving model ...
# Validation loss decreased (0.231589 --> 0.229459).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# Validation loss decreased (0.229459 --> 0.227321).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# Validation loss decreased (0.227321 --> 0.224861).  Saving model ...
# Validation loss decreased (0.224861 --> 0.223413).  Saving model ...
# Validation loss decreased (0.223413 --> 0.220660).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.220660 --> 0.219984).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# Validation loss decreased (0.219984 --> 0.219879).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# Validation loss decreased (0.219879 --> 0.219539).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# Validation loss decreased (0.219539 --> 0.216601).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# Validation loss decreased (0.216601 --> 0.214470).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.214470 --> 0.214186).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# EarlyStopping counter: 33 out of 50
# EarlyStopping counter: 34 out of 50
# EarlyStopping counter: 35 out of 50
# EarlyStopping counter: 36 out of 50
# EarlyStopping counter: 37 out of 50
# EarlyStopping counter: 38 out of 50
# EarlyStopping counter: 39 out of 50
# Validation loss decreased (0.214186 --> 0.211124).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.211124 --> 0.210036).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# Validation loss decreased (0.210036 --> 0.208612).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.208612 --> 0.208264).  Saving model ...
# Validation loss decreased (0.208264 --> 0.207728).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# EarlyStopping counter: 33 out of 50
# EarlyStopping counter: 34 out of 50
# EarlyStopping counter: 35 out of 50
# EarlyStopping counter: 36 out of 50
# EarlyStopping counter: 37 out of 50
# EarlyStopping counter: 38 out of 50
# EarlyStopping counter: 39 out of 50
# EarlyStopping counter: 40 out of 50
# EarlyStopping counter: 41 out of 50
# EarlyStopping counter: 42 out of 50
# Validation loss decreased (0.207728 --> 0.207128).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# EarlyStopping counter: 33 out of 50
# EarlyStopping counter: 34 out of 50
# EarlyStopping counter: 35 out of 50
# EarlyStopping counter: 36 out of 50
# EarlyStopping counter: 37 out of 50
# EarlyStopping counter: 38 out of 50
# Validation loss decreased (0.207128 --> 0.205804).  Saving model ...
# Validation loss decreased (0.205804 --> 0.204103).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.204103 --> 0.200938).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# EarlyStopping counter: 33 out of 50
# EarlyStopping counter: 34 out of 50
# EarlyStopping counter: 35 out of 50
# EarlyStopping counter: 36 out of 50
# EarlyStopping counter: 37 out of 50
# EarlyStopping counter: 38 out of 50
# EarlyStopping counter: 39 out of 50
# EarlyStopping counter: 40 out of 50
# EarlyStopping counter: 41 out of 50
# EarlyStopping counter: 42 out of 50
# EarlyStopping counter: 43 out of 50
# EarlyStopping counter: 44 out of 50
# EarlyStopping counter: 45 out of 50
# EarlyStopping counter: 46 out of 50
# EarlyStopping counter: 47 out of 50
# EarlyStopping counter: 48 out of 50
# EarlyStopping counter: 49 out of 50
# EarlyStopping counter: 50 out of 50
# Early stopping
# auc: 0.9138218048697287, ap: 0.9000068277724533

# %%
import statistics

print(f'AUC: {statistics.mean(auc_list)}, {statistics.stdev(auc_list)}')
print(f'AP: {statistics.mean(ap_list)}, {statistics.stdev(ap_list)}')
# Out:
# AUC: 0.9100877512024033, 0.007723909849077316
# AP: 0.8917769733866674, 0.01237942594912229
